# %% [markdown]
# ## <img src="./fiuba.jpg" align="right" width="150" />
# #### Procesamiento Digital de Señales
#
# # Trabajo Práctico 2
# #### Lucas Dórdolo
#
# ***
# ## Filtrado

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>1)</b> Para el siguiente filtro digital se pide:
#
# </div>

# %% [markdown]
#  $$ y(k) = \frac{1}{N} \sum_{i=0}^{N-1} x(k-i)  $$
#
#  Para N = [3; 5]

# %% [markdown]
#    a) El diagrama de polos y ceros y su respuesta de módulo y fase

# %% [markdown]
# <img src="./escriba_aqui.png" align="center" width="50%" />

# %% [markdown]
#    b) Corrobore su respuesta mediante la simulación computacional

# %%
## Inicialización del Notebook del TP4

import numpy as np
from pandas import DataFrame
from IPython.display import HTML
from scipy import signal as sig
from  matplotlib import patches
import matplotlib as mpl
import scipy.io as scipyio
import matplotlib.pyplot as plt
import scipy.fftpack as sc

# Insertar aquí el código para inicializar tu notebook
########################################################

import matplotlib as mpl
#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)

import matplotlib.pyplot as plt

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
# NO ES IMPORTANTE
fig_sz_x = 14
fig_sz_y = 13
fig_dpi = 80 # dpi

fig_font_family = 'Ubuntu'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
plt.rcParams.update({'font.family':fig_font_family})

def vertical_flaten(a):
    
    return a.reshape(a.shape[0],1)

def zplane(b,a,filename=None):
    """Plot the complex z-plane given a transfer function.
    """

    # get a figure/plot
    ax = plt.subplot(111)

    # create the unit circle
    uc = patches.Circle((0,0), radius=1, fill=False,
                        color='black', ls='dashed')
    ax.add_patch(uc)

    # The coefficients are less than 1, normalize the coeficients
    if np.max(b) > 1:
        kn = np.max(b)
        b = b/float(kn)
    else:
        kn = 1

    if np.max(a) > 1:
        kd = np.max(a)
        a = a/float(kd)
    else:
        kd = 1
        
    # Get the poles and zeros
    p = np.roots(a)
    z = np.roots(b)
    k = kn/float(kd)
    
    # Plot the zeros and set marker properties    
    t1 = plt.plot(z.real, z.imag, 'go', ms=10)
    plt.setp( t1, markersize=10.0, markeredgewidth=1.0,
              markeredgecolor='k', markerfacecolor='g')

    # Plot the poles and set marker properties
    t2 = plt.plot(p.real, p.imag, 'rx', ms=10)
    plt.setp( t2, markersize=12.0, markeredgewidth=3.0,
              markeredgecolor='r', markerfacecolor='r')

    ax.spines['left'].set_position('center')
    ax.spines['bottom'].set_position('center')
    ax.spines['right'].set_visible(False)
    ax.spines['top'].set_visible(False)

    # set the ticks
    r = 1.5; plt.axis('scaled'); plt.axis([-r, r, -r, r])
    ticks = [-1, -.5, .5, 1]; plt.xticks(ticks); plt.yticks(ticks)

    if filename is None:
        plt.show()
    else:
        plt.savefig(filename)
    

    return z, p, k

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################
a = [1/3, 1/3, 1/3]
b = [1, 0, 0]

ww, hh = sig.freqz(np.array(a), b[0])
ww = ww / np.pi

plt.figure(1)

plt.plot(ww, 20 * np.log10(abs(hh)), label='3 muestras')

plt.title('FIR promediador')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')
plt.grid(which='both', axis='both')

axes_hdl = plt.gca()
axes_hdl.legend()

plt.show()

plt.figure(2)

plt.plot(ww, np.angle(hh), label='3 muestras')

plt.title('FIR promediador')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Fase')
plt.grid(which='both', axis='both')

axes_hdl = plt.gca()
axes_hdl.legend()

plt.show()

plt.figure(3)


zplane(a, b)
# Out:
# (array([-0.5+0.8660254j, -0.5-0.8660254j]), array([0., 0.]), 1.0)

# %%
a = [1/5,1/5,1/5,1/5,1/5]
b = [1, 0, 0, 0, 0]

ww, hh = sig.freqz(np.array(a), b[0])
ww = ww / np.pi

plt.figure(1)

plt.plot(ww, 20 * np.log10(abs(hh)), label='5 muestras')

plt.title('FIR promediador')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')
plt.grid(which='both', axis='both')

axes_hdl = plt.gca()
axes_hdl.legend()

plt.show()

plt.figure(2)

plt.plot(ww, np.angle(hh), label='5 muestras')

plt.title('FIR promediador')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Fase')
plt.grid(which='both', axis='both')

axes_hdl = plt.gca()
axes_hdl.legend()

plt.show()

plt.figure(3)

zplane(a, b)
# Out:
# (array([ 0.30901699+0.95105652j,  0.30901699-0.95105652j,
#         -0.80901699+0.58778525j, -0.80901699-0.58778525j]),
#  array([0., 0., 0., 0.]),
#  1.0)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>2)</b> Para el siguiente filtro digital se pide:
#
# </div>

# %% [markdown]
# $$ h(k) = (-1, 1) $$

# %% [markdown]
#    a) El diagrama de polos y ceros y su respuesta de módulo y fase

# %% [markdown]
# <img src="./escriba_aqui.png" align="center" width="50%" />

# %% [markdown]
#    b) Corrobore su respuesta mediante simulación computacional

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

a = [-1,1]
b = [1, 0]

ww, hh = sig.freqz(np.array(a), b[0])
ww = ww / np.pi

plt.figure(1)

plt.plot(ww, 20 * np.log10(abs(hh)), label='longitud 2')

plt.title('FIR tipo IV')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')
plt.grid(which='both', axis='both')

axes_hdl = plt.gca()
axes_hdl.legend()

plt.show()

plt.figure(2)

plt.plot(ww, np.angle(hh), label='longitud 2')

plt.title('FIR tipo IV')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Fase')
plt.grid(which='both', axis='both')

axes_hdl = plt.gca()
axes_hdl.legend()

plt.show()

plt.figure(3)

zplane(a, b)
# Out:
# /home/lucas/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log10
# (array([1.]), array([0.]), 1.0)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>3)</b> Para el siguiente filtro digital se pide:
#
# </div>

# %% [markdown]
# <img src="./comb.png" align="center" width="30%" />
#
#
# Para $N= (2; 4)$ y $b = -1$

# %% [markdown]
#    a) El diagrama de polos y ceros y su respuesta de módulo y fase

# %% [markdown]
# <img src="./escriba_aqui.png" align="center" width="50%" />

# %% [markdown]
#    b) Corrobore su respuesta mediante simulación computacional

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

a = [1, 0, -1]
b = [1, 0, 0]

ww, hh = sig.freqz(np.array(a), b[0])
ww = ww / np.pi

plt.figure(1)

plt.plot(ww, 20 * np.log10(abs(hh)), label='longitud 3')

plt.title('FIR tipo III')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')
plt.grid(which='both', axis='both')

axes_hdl = plt.gca()
axes_hdl.legend()

plt.show()

plt.figure(2)

plt.plot(ww, np.angle(hh), label='longitud 3')

plt.title('FIR tipo III')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Fase')
plt.grid(which='both', axis='both')

axes_hdl = plt.gca()
axes_hdl.legend()

plt.show()

plt.figure(3)

zplane(a, b)
# Out:
# /home/lucas/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: RuntimeWarning: divide by zero encountered in log10
# (array([ 1., -1.]), array([0., 0.]), 1.0)

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

a = [1, 0 ,0 ,0 ,-1]
b = [1, 0, 0, 0, 0]

ww, hh = sig.freqz(np.array(a), b[0])
ww = ww / np.pi

plt.figure(1)

plt.plot(ww, 20 * np.log10(abs(hh)), label='longitud 5')

plt.title('FIR tipo III')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')
plt.grid(which='both', axis='both')

axes_hdl = plt.gca()
axes_hdl.legend()

plt.show()

plt.figure(2)

plt.plot(ww, np.angle(hh), label='longitud 5')

plt.title('FIR tipo III')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Fase')
plt.grid(which='both', axis='both')

axes_hdl = plt.gca()
axes_hdl.legend()

plt.show()

plt.figure(3)

zplane(a, b)
# Out:
# /home/lucas/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: RuntimeWarning: divide by zero encountered in log10
#   del sys.path[0]
# (array([-1.00000000e+00+0.j,  5.55111512e-17+1.j,  5.55111512e-17-1.j,
#          1.00000000e+00+0.j]), array([0., 0., 0., 0.]), 1.0)

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>4)</b> En el archivo <i>ECG_TP4.mat</i> encontrará un registro electrocardiográfico (ECG) registrado durante una prueba de esfuerzo, junto con una serie de variables descriptas a continuación. Diseñe y aplique los filtros digitales necesarios para mitigar las siguientes fuentes de contaminación:
# </div>

# %% [markdown]
#  - Ruido causado por el movimiento de los electrodos (Alta frecuencia)
#  - Ruido muscular (Alta frecuencia)
#  - Movimiento de la línea de base del ECG, inducido en parte por la respiración (Baja frecuencia)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Los latidos presentes en el registro de ECG, alineados y clasificados (de origen normal y ventricular) poseen las siguientes características temporales y frecuenciales:
# </div>

# %% [markdown]
# <img src="./latidos_tiempo.png" align="center" width="80%" />
#
# <img src="./latido_promedio.png" align="center" width="80%" />
#
# <img src="./latidos_espectro.png" align="center" width="80%" />

# %% [markdown]
# ### Archivo *ECG_TP4.mat*
# (variables)
#  - **ecg_lead**: Registro de ECG muestreado a $fs=1$ KHz durante una prueba de esfuerzo
#  - **qrs_pattern1**: Complejo de ondas QRS normal
#  - **heartbeat_pattern1**: Latido normal
#  - **heartbeat_pattern2**: Latido de origen ventricular
#  - **qrs_detections**: vector con las localizaciones (en # de muestras) donde ocurren los latidos
#
# a) Establezca una plantilla de diseño para los filtros digitales que necesitará para que la señal de ECG se asemeje a los latidos promedio en cuanto a *suavidad* de los trazos y nivel isoeléctrico nulo.

# %%
#Cargamos el archivo
mat = scipyio.loadmat('ECG_TP4.mat')

#y cada una de sus variables
ecg = mat['ecg_lead']  
qrs = mat['qrs_pattern1']
latido_normal = mat['heartbeat_pattern1']
latido_ventricular = mat['heartbeat_pattern2']
qrs_deteccion = mat['qrs_detections']

# %%
fs = 1000
N = len(ecg)
t = np.linspace(0.0, (N-1)/fs, N)

plt.figure(1)

#Representación temporal de una porción 4 a 5seg (sin interferencia)
plt.plot(t[4000:5000], ecg[4000:5000])

plt.title('ECG')
plt.xlabel('Tiempo [s]')
plt.ylabel('Amplitud')



f = np.linspace(0.0, fs//18, N//18)
#representación espectral hasta 60Hz
spectrum = np.abs(sc.fft(ecg.flatten()))
half = spectrum[:N//18] 

plt.figure(2)


plt.plot(f, half)

plt.title('Espectro del ECG')
plt.xlabel('Frecuencia [Hz]')
plt.ylabel('Amplitud ')
# Out:
# Text(0, 0.5, 'Amplitud ')

# %%
# Defina la plantilla del filtro

fs0 = 0.4 # fin de la banda de detenida 0
fc0 = 1.55 # comienzo de la banda de paso
fc1 = 35 # fin de la banda de paso
fs1 = 40 # comienzo de la banda de detenida 1

# %% [markdown]
# b) ¿Cómo obtuvo dichos valores?

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# c) Diseñe **al menos** dos filtros FIR y dos IIR para su comparación. Verifique que la respuesta en frecuencia responda a la plantilla de diseño

# %%
#Cargamos los coeficientes del filtro
data_pb1 = np.load('pb_eq.npz')
h_pb1 = data_pb1['ba']
b_pb1 = h_pb1[0]
a_pb1 = h_pb1[1]

data_pa1 = np.load('pa_eq.npz')
h_pa1 = data_pa1['ba']
b_pa1 = h_pa1[0]
a_pa1 = h_pa1[1]

#Obtenemos la respuesta en frecuencia del filtro
w, g = sig.freqz(b_pb1, a_pb1)
w = (w / np.pi) / 2

plt.figure(1)
# Crear una figura de 8x6 puntos de tamaño, 80 puntos por pulgada
plt.figure(figsize=(8, 8), dpi=120)

#Graficamos el modulo del filtro en escala logaritmica
plt.subplot(331)
plt.plot(w, 20 * np.log10(abs(g)))

plt.title('FIR Equiripple Pasabajos')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')

#Graficamos la fase del filtro
plt.subplot(337)
plt.plot(w, np.angle(g))

plt.title('FIR Equiripple  Pasabajos')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Fase en radianes')


#Obtenemos la respuesta en frecuencia del filtro
w, g = sig.freqz(b_pa1, a_pa1)
w = (w / np.pi) / 2

#Graficamos el modulo del filtro en escala logaritmica
plt.subplot(333)
plt.plot(w, 20 * np.log10(abs(g)))

plt.title('FIR Equiripple  Pasaaltos')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')


#Graficamos la fase del filtro
plt.subplot(339)
plt.plot(w, np.angle(g))

plt.title('FIR Equiripple  Pasaaltos')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Fase en radianes')


plt.show()

# %%
#Cargamos los coeficientes del filtro
#flattop
data_pb2 = np.load('pb_ft.npz')
h_pb2 = data_pb2['ba']
b_pb2 = h_pb2[0]
a_pb2 = h_pb2[1]

data_pa2 = np.load('pa_ft.npz')
h_pa2 = data_pa2['ba']
b_pa2 = h_pa2[0]
a_pa2 = h_pa2[1]

#Obtenemos la respuesta en frecuencia del filtro
w, g = sig.freqz(b_pb2, a_pb2)
w = (w / np.pi) / 2

plt.figure(1)
# Crear una figura de 8x6 puntos de tamaño, 80 puntos por pulgada
plt.figure(figsize=(8, 8), dpi=120)

#Graficamos el modulo del filtro en escala logaritmica
plt.subplot(331)
plt.plot(w, 20 * np.log10(abs(g)))

plt.title('FIR Flattop Pasabajos')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')

#Graficamos la fase del filtro
plt.subplot(337)
plt.plot(w, np.angle(g))

plt.title('FIR Flattop Pasabajos')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Fase en radianes')


#Obtenemos la respuesta en frecuencia del filtro
w, g = sig.freqz(b_pa2, a_pa2)
w = (w / np.pi) / 2

#Graficamos el modulo del filtro en escala logaritmica
plt.subplot(333)
plt.plot(w, 20 * np.log10(abs(g)))

plt.title('FIR Flattop Pasaaltos')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')


#Graficamos la fase del filtro
plt.subplot(339)
plt.plot(w, np.angle(g))

plt.title('FIR Flattop Pasaaltos')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Fase en radianes')


plt.show()

# %%
#Cargamos los coeficientes del filtro
#butterworth
data_pb3 = np.load('pb_bt.npz')
h_pb3 = data_pb3['ba']
b_pb3 = h_pb3[0]
a_pb3 = h_pb3[1]

data_pa3 = np.load('pa_bt.npz')
h_pa3 = data_pa3['ba']
b_pa3 = h_pa3[0]
a_pa3 = h_pa3[1]

#Obtenemos la respuesta en frecuencia del filtro
w, g = sig.freqz(b_pb3, a_pb3)
w = (w / np.pi) / 2

plt.figure(1,figsize=(8, 8), dpi=120)


#Graficamos el modulo del filtro en escala logaritmica
plt.subplot(331)
plt.plot(w, 20 * np.log10(abs(g)))

plt.title('IIR  Butterworth Pasabajos')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')

#Graficamos la fase del filtro
plt.subplot(337)
plt.plot(w, np.angle(g))

plt.title('IIR  Butterworth Pasabajos')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Fase en radianes')


#Obtenemos la respuesta en frecuencia del filtro
w, g = sig.freqz(b_pa3, a_pa3)
w = (w / np.pi) / 2

#Graficamos el modulo del filtro en escala logaritmica
plt.subplot(333)
plt.plot(w, 20 * np.log10(abs(g)))

plt.title('IIR  Butterworth Pasaaltos')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')


#Graficamos la fase del filtro
plt.subplot(339)
plt.plot(w, np.angle(g))

plt.title('IIR  Butterworth Pasaaltos')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Fase en radianes')


plt.show()

# %%
#Cargamos los coeficientes del filtro
#chebychev1
data_pb4 = np.load('pb_ch1.npz')
h_pb4 = data_pb3['ba']
b_pb4 = h_pb4[0]
a_pb4 = h_pb4[1]

data_pa4 = np.load('pa_ch1.npz')
h_pa4 = data_pa4['ba']
b_pa4 = h_pa4[0]
a_pa4 = h_pa4[1]

#Obtenemos la respuesta en frecuencia del filtro
w, g = sig.freqz(b_pb4, a_pb4)
w = (w / np.pi) / 2

plt.figure(1,figsize=(8, 8), dpi=120)


#Graficamos el modulo del filtro en escala logaritmica
plt.subplot(331)
plt.plot(w, 20 * np.log10(abs(g)))

plt.title('IIR  Chebychev1 Pasabajos')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')

#Graficamos la fase del filtro
plt.subplot(337)
plt.plot(w, np.angle(g))

plt.title('IIR  Chebychev1 Pasabajos')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Fase en radianes')


#Obtenemos la respuesta en frecuencia del filtro
w, g = sig.freqz(b_pa4, a_pa4)
w = (w / np.pi) / 2

#Graficamos el modulo del filtro en escala logaritmica
plt.subplot(333)
plt.plot(w, 20 * np.log10(abs(g)))

plt.title('IIR  Chebychev1 Pasaaltos')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Modulo [dB]')


#Graficamos la fase del filtro
plt.subplot(339)
plt.plot(w, np.angle(g))

plt.title('IIR  Chebychev1 Pasaaltos')
plt.xlabel('Frequencia normalizada')
plt.ylabel('Fase en radianes')


plt.show()

# %% [markdown]
# d) Evalúe el rendimiento de los filtros que haya diseñado:
#
#  1. Verifique que filtra las señales interferentes
#  2. Verifique que es inocuo en las zonas donde no hay interferentes

# %%
# Segmentos de interés #
########################
# Puede tomar como referencia los siguientes segmentos, aunque si lo considera, también
# puede incluir otros que considere importantes para evaluar el rendimiento.

zonas_con_interf_baja_frec = ( 
        np.array([12, 12.4]) *60*fs, # minutos a muestras
        np.array([15, 15.2]) *60*fs, # minutos a muestras
        )


zonas_sin_interf = ( 
        np.array([5, 5.2]) *60*fs, # minutos a muestras
        [4000, 5500], # muestras
        [10e3, 11e3], # muestras
        )

##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# SIN INTERFERENCIA
for i in range(3):

    inicial = int(zonas_sin_interf[i][0])
    final = int(zonas_sin_interf[i][1]) 
    
    N = len(ecg[inicial:final])
    t = np.linspace(0, (N-1)/fs, N).flatten()
    

    y_eq_pb = sig.filtfilt(b_pb1,a_pb1,ecg.flatten())
    y_eq_pa = sig.filtfilt(b_pa1,a_pa1,y_eq_pb.flatten())
    
    y_ft_pb = sig.filtfilt(b_pb2,a_pb2,ecg.flatten())
    y_ft_pa = sig.filtfilt(b_pa2,a_pa2,y_ft_pb.flatten())
    
    y_bt_pb = sig.filtfilt(b_pb3,a_pb3,ecg.flatten())
    y_bt_pa = sig.filtfilt(b_pa3,a_pa3,y_bt_pb.flatten())
    
    y_ch1_pb = sig.filtfilt(b_pb4,a_pb4,ecg.flatten())
    y_ch1_pa = sig.filtfilt(b_pa4,a_pa4,y_ch1_pb.flatten())
    

    plt.figure(i + 1,figsize =(6,6),dpi = 120)

 
    plt.plot(t, ecg[inicial:final], label="Original")
    plt.plot(t, y_eq_pa[inicial:final], label="Pasabanda_FIR_eq")
    plt.plot(t, y_ft_pa[inicial:final], label="Pasabanda_FIR_ft")
    plt.plot(t, y_bt_pa[inicial:final], label="Pasabanda_IIR_bt")
    plt.plot(t, y_ch1_pa[inicial:final], label="Pasabanda_IIR_ch1")

    
    plt.title('Registro ECG sin interferencia')
    plt.xlabel('Tiempo [s]')
    plt.ylabel('Amplitud')
    plt.grid(which='both', axis='both')
    axes_hdl = plt.gca()
    axes_hdl.legend()

#CON INTERFERENCIA
for i in range(2):

    inicial = int(zonas_con_interf_baja_frec[i][0])
    final = int(zonas_con_interf_baja_frec[i][1]) 
    
    N = len(ecg[inicial:final])
    t = np.linspace(0, (N-1)/fs, N).flatten()
    

    y_eq_pb = sig.filtfilt(b_pb1,a_pb1,ecg.flatten())
    y_eq_pa = sig.filtfilt(b_pa1,a_pa1,y_eq_pb.flatten())
    
    y_ft_pb = sig.filtfilt(b_pb2,a_pb2,ecg.flatten())
    y_ft_pa = sig.filtfilt(b_pa2,a_pa2,y_ft_pb.flatten())
    
    y_bt_pb = sig.filtfilt(b_pb3,a_pb3,ecg.flatten())
    y_bt_pa = sig.filtfilt(b_pa3,a_pa3,y_bt_pb.flatten())

    y_ch1_pb = sig.filtfilt(b_pb4,a_pb4,ecg.flatten())
    y_ch1_pa = sig.filtfilt(b_pa4,a_pa4,y_ch1_pb.flatten())
       

    plt.figure(i + 4,figsize =(6,6),dpi = 120)
    
    #Graficamos señal sin filtrar
    plt.plot(t, ecg[inicial:final], label="Original")
    plt.plot(t, y_eq_pa[inicial:final], label="Pasabanda_FIR_eq")
    plt.plot(t, y_ft_pa[inicial:final], label="Pasabanda_FIR_ft")
    plt.plot(t, y_bt_pa[inicial:final], label="Pasabanda_IIR_bt")
    plt.plot(t, y_ch1_pa[inicial:final], label="Pasabanda_IIR_ch1")

    
    plt.title('Registro ECG con interferencia baja frecuencia')
    plt.xlabel('Tiempo [s]')
    plt.ylabel('Amplitud')
    plt.grid(which='both', axis='both')
    axes_hdl = plt.gca()
    axes_hdl.legend()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>5)</b> Utilice las siguientes metodologías <b>no lineales</b> de estimación-substracción para la remoción de la interferencia de línea de base, y compare con las técnicas lineales del punto anterior en las mismas regiones. Luego discuta las ventajas y desventajas de cada técnica.
# </div>

# %% [markdown]
# a) Estimación del movimiento de línea de base a partir del filtrado de mediana. A partir de la siguiente estimación del movimiento de línea de base
#
# $$ \hat{b} = \mathop{med}_{600} \{ \mathop{med}_{200} \{s\} \} $$
#
# Donde $s$ representa la señal de ECG a partir de la que estimamos el movimiento de la línea de base $ \hat{b}$. El operador $\mathop{med}_{200}$ calcula muestra a muestra la mediana en los 200 ms previos a la muestra actual. Luego dicha estimación la substraemos para estimar la actividad eléctrica cardíaca $\hat{x}$
#
# $$ \hat{x} = s - \hat{b} $$

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Puede utilizar la implementación del <a href="https://docs.scipy.org/doc/scipy/reference/tutorial/signal.html#median-filter">filtro de mediana provista en <b>scipy.signal</b></a>
# </div>

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# b) Estimación del movimiento de línea de base a partir de los segmentos isoeléctricos de cada latido. A partir de las detecciones provistas, puede estimar aproximadamente el nivel isoeléctrico, es decir el momento donde la actividad eléctrica cardíaca es **nula**. El intervalo entre la onda P y Q, es un buen momento para estimar las características de las señales interferentes que originan el movimiento de la línea de base.
#
# <img src="./pq.png" align="center" width="80%" />
#
# Para la localización del segmento PQ puede valerse de la localización de cada latido (líneas rojas verticales) y a partir de la misma, anticipar un tiempo adecuado de manera tal de no incluir la onda P ni Q. Puede ayudarse con el latido promedio de un latido normal para establecer dicho intervalo.
#
# Recuerde que la señal de línea de base debe estar muestreada a la misma frecuencia que el ECG, por lo que debería remuestrear dicha señal (puede usar la función de interpolación spline para ello).

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Puede utilizar la función de interpolación <a href="https://docs.scipy.org/doc/scipy-0.18.1/reference/generated/scipy.interpolate.CubicSpline.html">spline <b>scipy.interpolate.CubicSpline</b></a>
# </div>

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>6)</b> Para la señal de ECG provista junto con este documento, aplique el concepto de <b>filtro adaptado</b> y otras técnicas de filtrado digital para diseñar un detector de latidos. Los patrones provistos son:
#
# </div>

# %% [markdown]
#  - **qrs_pattern1**: Complejo de ondas QRS normal
#  - **heartbeat_pattern1**: Latido normal
#  - **heartbeat_pattern2**: Latido de origen ventricular

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Ayuda:</b> Revise el concepto de filtro adaptado en <a href="http://en.wikipedia.org/wiki/Matched_filter">Wikipedia</a>, o la bibliografía de la materia (Porat 14.4.9).
# </div>

# %%
import scipy.io as sio

##########################################
# Acá podés generar los gráficos pedidos #
##########################################

# para listar las variables que hay en el archivo
#io.whosmat('ECG_TP4.mat')
mat_struct = sio.loadmat('./ECG_TP4.mat')

ecg_one_lead = vertical_flaten(mat_struct['ecg_lead'])
N = len(ecg_one_lead)

hb_1 = vertical_flaten(mat_struct['heartbeat_pattern1'])

plt.figure(1)
plt.plot(ecg_one_lead[5000:12000])

plt.figure(2)
plt.plot(hb_1)

# %% [markdown]
# a) Explique conceptualmente cómo podría realizar un detector de latidos con la señal resultante del filtro adaptado. Discuta la utilidad y limitaciones de este método.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Respuesta:</b> Escriba aquí su respuesta.
# </div>

# %% [markdown]
#
#    b) Realice la detección de los latidos, comparando las detecciones obtenidas con las que se incluyen en la variable **qrs_detections**. Proponga alguna métrica para cuantificar las diferencias.

# %%
##########################################
# Acá podés generar los gráficos pedidos #
##########################################
